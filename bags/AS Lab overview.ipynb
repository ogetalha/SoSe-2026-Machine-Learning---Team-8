# %% [markdown]
# # Autonomous Systems A Lab — Project Organization Notebook
#
# This notebook is a structured project companion for the **Autonomous Systems A Lab**.
#
# Use it to:
# - organize the team,
# - track responsibilities,
# - document progress,
# - prepare milestones,
# - collect evidence of practical work,
# - prepare final presentation and paper.
#
# Use the checkboxes `- [ ]` / `- [x]` to track what is done.
#
# > Recommendation: Commit this notebook regularly to your team GitHub repository.

# %% [markdown]
# ## Project context
#
# The lab is motivated by **truck platooning** and ADAS.
#
# The project combines:
# 1. SVM-based line following,
# 2. scenario and requirements modelling,
# 3. communication/protocol specification,
# 4. timed automata and UPPAAL modelling,
# 5. control behaviour,
# 6. simulation and integration,
# 7. final presentation and documentation.

# %% [markdown]
# # 0. Team and Repository Setup
#
# ## Objective
# Prepare the technical and organisational foundation.
#
# ## Checklist
# - [ ] Team members are defined.
# - [ ] GitHub repository is created.
# - [ ] Professors are invited: `shenkler`, `mahirsch`.
# - [ ] Research assistants are invited: `AAT24`, `Krypto-Klaus`, `NordBaha`, `DomeDre`.
# - [ ] Repository has a clear folder structure.
# - [ ] All members can push and pull.
# - [ ] This notebook is committed.
# - [ ] Responsibilities are documented.
#
# ## Deadline
# - May 15 during the lab session, ideally earlier.
#
# ## Suggested repository structure
# ```text
# project-root/
# ├── notebooks/
# ├── src/
# ├── models/
# ├── data/
# ├── results/
# └── documentation/
# ```

# %%
team_name = "TODO"
repository_url = "TODO"

team_members = [
    {"name": "TODO", "role": "TODO", "main_responsibility": "TODO"},
    {"name": "TODO", "role": "TODO", "main_responsibility": "TODO"},
]

team_members

# %% [markdown]
# # 1. Responsibility Matrix
#
# ## Objective
# Divide the project into clear tasks and assign responsibilities.
#
# ## Checklist
# - [ ] Overall task list created.
# - [ ] Each task has a short summary.
# - [ ] Each task has one responsible member.
# - [ ] Each task has a deadline.
# - [ ] Progress status is documented.
# - [ ] Finished tasks include finishing date.
# - [ ] Matrix is updated continuously.
#
# | # | Task | Short Summary | Responsible | Todo / Deadline | Done / Finishing Date |
# |---|------|---------------|-------------|-----------------|-----------------------|
# | 1 | SVM line following | Train and evaluate SVM classifier | TODO | TODO | TODO |
# | 2 | Scenario modelling | Identify and model scenarios | TODO | TODO | TODO |
# | 3 | Communication protocol | Define signals/events/protocol | TODO | TODO | TODO |
# | 4 | Control behaviour | Define distance/failure handling | TODO | TODO | TODO |
# | 5 | Simulation integration | Integrate components | TODO | TODO | TODO |
# | 6 | Final presentation | Demo and slides | TODO | TODO | TODO |
# | 7 | Final paper | Documentation | TODO | TODO | TODO |

# %% [markdown]
# # 2. Task 1 — SVM-Based Line Following
#
# ## Objective
# Implement an **SVM-based line-following approach** using scikit-learn.
#
# ## Required elements
# - version for lane following,
# - own test data,
# - OpenCV usage,
# - parameter and kernel optimization,
# - CARLA competition environment,
# - CARLA input to refine line following,
# - Science Truck data to refine final SVM.
#
# ## Checklist — Preparation
# - [ ] Lab 05 to 07 completed.
# - [ ] Python environment works.
# - [ ] scikit-learn workflow understood.
# - [ ] OpenCV basics tested.
#
# ## Checklist — Dataset
# - [ ] Synthetic test data generated.
# - [ ] Feature representation defined.
# - [ ] Labels/classes defined.
# - [ ] Dataset documented.
# - [ ] Train/test split applied.
# - [ ] CARLA data considered.
# - [ ] Science Truck data integrated.
#
# ## Checklist — Model
# - [ ] Linear SVM trained.
# - [ ] RBF SVM trained.
# - [ ] Parameter `C` investigated.
# - [ ] Parameter `gamma` investigated.
# - [ ] Feature scaling applied.
# - [ ] Pipeline used to avoid data leakage.
# - [ ] Best model selected.
#
# ## Checklist — Evaluation
# - [ ] Accuracy reported.
# - [ ] Confusion matrix reported.
# - [ ] Critical scenarios identified.
# - [ ] Limitations discussed.
# - [ ] Trained model saved.
# - [ ] Notebook uploaded to Moodle per person.
# - [ ] Final model committed to GitHub.
#
# ## Deadlines
# - May 15: finalize and present lab exercises 01–07; upload all `.ipynb` files to Moodle per person.
# - May 18: gather detailed data in Science Truck and refine SVM.
# - May 19: upload trained SVM based on gathered data until EOB.
# - May 20: test SVM and gather additional critical scenarios.
# - May 21: final upload to GitHub until EOB.
# - May 22: competition in Science Truck starting 09:00.

# %%
task_1_status = {
    "synthetic_data_created": False,
    "opencv_used": False,
    "linear_svm_trained": False,
    "rbf_svm_trained": False,
    "parameters_optimized": False,
    "carla_data_used": False,
    "science_truck_data_used": False,
    "final_model_uploaded": False,
}
task_1_status

# %% [markdown]
# # 3. Task 2 — Scenario Identification and Requirements
#
# ## Objective
# Identify relevant scenarios, requirements, and timing behaviour.
#
# Each group member is responsible for at least one scenario.
#
# ## Checklist
# - [ ] Each group member selected at least one scenario.
# - [ ] Scenario descriptions written.
# - [ ] Functional requirements identified.
# - [ ] Non-functional requirements identified.
# - [ ] Timing requirements identified.
# - [ ] Safety requirements identified.
# - [ ] Assumptions documented.
# - [ ] Scenarios modelled using SysML/UML.
# - [ ] Models committed to GitHub.
#
# ## Milestone 1
# - Due: June 4, EOB.

# %%
scenarios = [
    {
        "scenario_name": "TODO",
        "responsible_member": "TODO",
        "short_description": "TODO",
        "functional_requirements": ["TODO"],
        "timing_requirements": ["TODO"],
        "safety_requirements": ["TODO"],
        "model_file": "TODO"
    }
]
scenarios

# %% [markdown]
# # 4. Task 3 — Communication Data, Signals, Events, and Protocols
#
# ## Objective
# Identify data/signals/events required for interaction and communication between trucks.
#
# Specify an appropriate protocol for each scenario. Use Timed Automata and UPPAAL.
#
# ## Checklist
# - [ ] Required data between trucks identified.
# - [ ] Required signals listed.
# - [ ] Required events listed.
# - [ ] Sender and receiver defined.
# - [ ] Timing assumptions defined.
# - [ ] Protocol defined for each scenario.
# - [ ] Communication failure considered.
# - [ ] Timed automata created.
# - [ ] UPPAAL model created.
# - [ ] Models committed to GitHub.
#
# ## Milestone 2
# - Due: June 11, EOB.

# %%
communication_items = [
    {
        "name": "TODO",
        "type": "data/signal/event",
        "sender": "TODO",
        "receiver": "TODO",
        "meaning": "TODO",
        "timing_constraint": "TODO",
        "related_scenario": "TODO"
    }
]
communication_items

# %% [markdown]
# # 5. Task 4 — Control Behaviour
#
# ## Objective
# Identify relevant control behaviour for the trucks.
#
# Guiding questions:
# - How can distance to the preceding truck be guaranteed?
# - What happens during communication failure?
# - Is the system robust and stable?
# - Which fallback behaviour is required?
#
# Use Timed Automata and UPPAAL.
#
# ## Checklist
# - [ ] Relevant control behaviours identified.
# - [ ] Distance-keeping specified.
# - [ ] Lane-following linked to SVM results.
# - [ ] Failure cases identified.
# - [ ] Communication failure behaviour specified.
# - [ ] Robustness assumptions documented.
# - [ ] Stability considerations documented.
# - [ ] UPPAAL model created or extended.
# - [ ] Control model committed to GitHub.
#
# ## Milestone 3
# - Due: June 18, EOB.

# %%
control_behaviours = [
    {
        "behaviour_name": "TODO",
        "related_scenario": "TODO",
        "input_signals": ["TODO"],
        "control_decision": "TODO",
        "safety_condition": "TODO",
        "failure_handling": "TODO",
        "model_file": "TODO"
    }
]
control_behaviours

# %% [markdown]
# # 6. Task 5 — Integration and Simulation
#
# ## Objective
# Implement a simulation integrating the specific tasks.
#
# The simulation should combine:
# - SVM line following,
# - scenario logic,
# - communication protocol,
# - control behaviour,
# - timing assumptions.
#
# ## Checklist
# - [ ] Simulation goal defined.
# - [ ] Simulation architecture defined.
# - [ ] Inputs and outputs specified.
# - [ ] SVM component integrated.
# - [ ] Communication behaviour integrated.
# - [ ] Control behaviour integrated.
# - [ ] At least one scenario simulated.
# - [ ] Critical scenario simulated.
# - [ ] Results documented.
# - [ ] Simulation committed to GitHub.
#
# ## Milestone 5
# - Due: June 25, EOB.

# %%
simulation_plan = {
    "simulation_goal": "TODO",
    "integrated_components": ["TODO"],
    "scenarios_to_simulate": ["TODO"],
    "expected_outputs": ["TODO"],
    "result_files": ["TODO"]
}
simulation_plan

# %% [markdown]
# # 7. Final Presentation
#
# ## Objective
# Present the complete project including a live demonstration.
#
# ## Checklist
# - [ ] Presentation structure defined.
# - [ ] Each group member has a speaking part.
# - [ ] Live demonstration prepared.
# - [ ] Technical backup prepared.
# - [ ] Results visualized.
# - [ ] Main limitations discussed.
# - [ ] Each group member can answer questions.
# - [ ] Final slides committed to GitHub.
#
# ## Requirements
# - Deadline: last week of semester, end of June.
# - Live demonstration: approximately 15 minutes.
# - Every group member must be able to answer questions.

# %% [markdown]
# # 8. Final Paper / Documentation
#
# ## Objective
# Document the complete project in scientific form.
#
# ## Required content
# - motivation,
# - scenario descriptions,
# - requirements,
# - SysML/UML models,
# - Timed Automata / UPPAAL models,
# - SVM approach,
# - datasets and evaluation,
# - simulation,
# - results,
# - limitations,
# - references.
#
# ## Checklist
# - [ ] LaTeX template prepared.
# - [ ] Motivation written.
# - [ ] Models included.
# - [ ] SVM approach documented.
# - [ ] Experiments documented.
# - [ ] Simulation documented.
# - [ ] Limitations discussed.
# - [ ] References included.
# - [ ] Paper reviewed by all members.
# - [ ] Final document uploaded to Moodle.
#
# ## Submission
# - Moodle submission: July 7, EOB.
# - Format: LaTeX format as used in seminars.
# - Length: 2 to 4 pages per member.

# %% [markdown]
# # 9. Weekly Progress Log
#
# ## Checklist
# - [ ] Progress updated weekly.
# - [ ] Open problems documented.
# - [ ] Decisions documented.
# - [ ] Next steps defined.
# - [ ] GitHub updated after important changes.
#
# | Date | Completed Work | Problems / Risks | Decisions | Next Steps |
# |------|----------------|------------------|-----------|------------|
# | YYYY-MM-DD | TODO | TODO | TODO | TODO |
# | YYYY-MM-DD | TODO | TODO | TODO | TODO |
# | YYYY-MM-DD | TODO | TODO | TODO | TODO |

# %% [markdown]
# # 10. Final Self-Check Before Submission
#
# ## Technical checklist
# - [ ] Repository is complete.
# - [ ] Notebooks run from top to bottom.
# - [ ] Data files or download instructions are available.
# - [ ] Models are saved.
# - [ ] Simulation can be executed or demonstrated.
# - [ ] Figures and results are reproducible.
#
# ## Scientific checklist
# - [ ] Problem is clearly defined.
# - [ ] Dataset is documented.
# - [ ] Methods are explained.
# - [ ] Results are evaluated.
# - [ ] Limitations are discussed.
# - [ ] References are included.
#
# ## Organisational checklist
# - [ ] Responsibilities are documented.
# - [ ] Milestones are fulfilled.
# - [ ] Moodle uploads are complete.
# - [ ] GitHub repository is up to date.
# - [ ] Final presentation is prepared.
# - [ ] Final paper is submitted.
